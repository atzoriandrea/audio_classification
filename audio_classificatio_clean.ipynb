# %%
import numpy as np
import tensorflow as tf
import os

# %%
classes = np.array(["air_conditioner","car_horn","children_playing","dog_bark","drilling","engine_idling","gun_shot","jackhammer","siren","street_music"])
classes_tensor = tf.convert_to_tensor(classes)

# %% [markdown]
# FULL DATASET ACQUISITION

# %%
dataset_path = "/mnt/3206BFFF191E7F85/UrbanSound8K/audio/"
folders = os.listdir(dataset_path)
train_files = []
for fold in os.listdir(dataset_path)[2:]:
  files = os.listdir(os.path.join(dataset_path, fold))
  for i,f in enumerate(files):
    files[i] = dataset_path+fold+"/"+f
  train_files.extend(files)

# %%
def decode_audio(audio_binary):
  audio, _ = tf.audio.decode_wav(audio_binary, desired_samples=128000, desired_channels=1)
  return tf.squeeze(audio, axis=-1)

# %% [markdown]
# DATASET CLEANING FOR WRONG WAV FILES

# %%
errors = 0
waste = []
for index, file in enumerate(train_files):
    audio_binary = tf.io.read_file(file)
    try:
        waveform = decode_audio(audio_binary)
    except tf.errors.InvalidArgumentError:
        waste.append(index)

for corrupted in waste[::-1]:
    del train_files[corrupted]

# %%
def get_label(file_path):
  parts = tf.strings.split(file_path, os.path.sep)
  filename = parts[-1]
  splitted = tf.strings.split(filename, "-")
  classID = splitted[1]
  classID = tf.strings.to_number(classID, tf.int32)
  # Note: You'll use indexing here instead of tuple unpacking to enable this
  # to work in a TensorFlow graph.
  return classes_tensor[classID]

# %%
def get_waveform_and_label(file_path):
  label = get_label(file_path)
  audio_binary = tf.io.read_file(file_path)
  waveform = decode_audio(audio_binary)
  return waveform, label

# %%
def float_wf(waveform):
    waveform = tf.cast(waveform, tf.float32)
    return waveform
def float_wf_and_label(audio, label):
  spectrogram = float_wf(audio)
  #spectrogram = tf.expand_dims(spectrogram, -1)
  label_id = tf.argmax(label == classes)
  return spectrogram, label_id

# %%
def preprocess_dataset(filelist):
    AUTOTUNE = -1
    files_ds = tf.data.Dataset.from_tensor_slices(filelist)
    waveform_ds = files_ds.map(get_waveform_and_label, num_parallel_calls=AUTOTUNE)
    ds = waveform_ds.map(float_wf_and_label, num_parallel_calls=AUTOTUNE)
    return ds

# %%
import random
def divide_by_class(fileslist):
    def get_label_id(file_path : str):
      parts = file_path.split(os.path.sep)
      filename = parts[-1]
      splitted = filename.split("-")
      classID = splitted[1]
      return  int(classID)

    bins = [[],[],[],[],[],[],[],[],[],[]]
    for file in fileslist:
        index = get_label_id(file)
        bins[index].append(file)
    return bins

def split(ds, train_percentage = 0.70, val_percentage = 0.10, test_percentage =0.2):
    total_files = len(ds)
    train_end_index = int(total_files*train_percentage)
    val_end_index = train_end_index + int(total_files*val_percentage)
    tr_s = ds[0:train_end_index]
    v_s = ds[train_end_index:val_end_index]
    te_s = ds[val_end_index:]
    return tr_s, v_s, te_s

def split_dataset(fileslist):
    random.shuffle(fileslist)
    bins = divide_by_class(fileslist)
    train = []
    val = []
    test = []
    for bin in bins:
        train_temp, val_temp, test_temp = split(bin)
        train.extend(train_temp)
        val.extend(val_temp)
        test.extend(test_temp)
    random.shuffle(train)
    random.shuffle(val)
    random.shuffle(test)
    return train, val, test

trainFiles, valFiles, testFiles = split_dataset(train_files)

# %%
train_set = preprocess_dataset(trainFiles)
val_set = preprocess_dataset(valFiles)
test_set = preprocess_dataset(testFiles)

# %% [markdown]
# MODEL AND PARAMETERS

# %%
from tensorflow.keras import layers
from tensorflow.keras import models
model = models.Sequential([
    layers.Input(shape=(128000,)),
    layers.Dense(64, activation='relu'),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.25),
    layers.Dropout(0.25),
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(10),
])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 64)                8192064
# _________________________________________________________________
# dense_5 (Dense)              (None, 128)               8320
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 128)               0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 128)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 8,218,186
# Trainable params: 8,218,186
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy'],
)

# %% [markdown]
# DATASETS PREPAIRING

# %%
del model

# %%
batch_size = 64
AUTOTUNE = -1
train_set = train_set.batch(batch_size)
train_set = train_set.cache().prefetch(AUTOTUNE)
val_set = val_set.batch(batch_size)
val_set = val_set.cache().prefetch(AUTOTUNE)
test_set = test_set.batch(batch_size)
test_set = test_set.cache().prefetch(AUTOTUNE)

# %%
EPOCHS = 100
history = model.fit(
    train_set,
    validation_data=val_set,
    epochs=EPOCHS,
)
# Out:
# Epoch 1/100
# 58/58 [==============================] - 3s 57ms/step - loss: 2.3457 - accuracy: 0.1229 - val_loss: 2.2390 - val_accuracy: 0.0173
# Epoch 2/100
# 58/58 [==============================] - 2s 26ms/step - loss: 2.5062 - accuracy: 0.0636 - val_loss: 2.2383 - val_accuracy: 0.0192
# Epoch 3/100
# 58/58 [==============================] - 1s 25ms/step - loss: 2.3060 - accuracy: 0.0568 - val_loss: 2.2220 - val_accuracy: 0.0308
# Epoch 4/100
# 58/58 [==============================] - 1s 25ms/step - loss: 2.1552 - accuracy: 0.0587 - val_loss: 2.1999 - val_accuracy: 0.0827
# Epoch 5/100
# 58/58 [==============================] - 2s 28ms/step - loss: 2.0176 - accuracy: 0.0655 - val_loss: 2.1768 - val_accuracy: 0.0692
# Epoch 6/100
# 58/58 [==============================] - 1s 25ms/step - loss: 1.8085 - accuracy: 0.0633 - val_loss: 2.1594 - val_accuracy: 0.1135
# Epoch 7/100
# 58/58 [==============================] - 2s 27ms/step - loss: 1.6169 - accuracy: 0.0852 - val_loss: 2.1821 - val_accuracy: 0.0981
# Epoch 8/100
# 58/58 [==============================] - 1s 25ms/step - loss: 1.4123 - accuracy: 0.0800 - val_loss: 2.1842 - val_accuracy: 0.1269
# Epoch 9/100
# 58/58 [==============================] - 1s 25ms/step - loss: 1.1775 - accuracy: 0.0846 - val_loss: 2.2592 - val_accuracy: 0.1212
# Epoch 10/100
# 58/58 [==============================] - 1s 25ms/step - loss: 1.0247 - accuracy: 0.0822 - val_loss: 2.3289 - val_accuracy: 0.1192
# Epoch 11/100
# 58/58 [==============================] - 1s 25ms/step - loss: 0.8894 - accuracy: 0.0909 - val_loss: 2.4799 - val_accuracy: 0.1250
# Epoch 12/100
# 58/58 [==============================] - 1s 25ms/step - loss: 0.7508 - accuracy: 0.0895 - val_loss: 2.5866 - val_accuracy: 0.1019
# Epoch 13/100
# 58/58 [==============================] - 1s 25ms/step - loss: 0.6197 - accuracy: 0.0925 - val_loss: 2.7614 - val_accuracy: 0.0981
# Epoch 14/100
# 58/58 [==============================] - 1s 25ms/step - loss: 0.5579 - accuracy: 0.0915 - val_loss: 2.8784 - val_accuracy: 0.1115
# Epoch 15/100
# 58/58 [==============================] - 1s 25ms/step - loss: 0.5338 - accuracy: 0.0999 - val_loss: 3.1016 - val_accuracy: 0.0865
# Epoch 16/100
# 58/58 [==============================] - 1s 25ms/step - loss: 0.4358 - accuracy: 0.0950 - val_loss: 3.1977 - val_accuracy: 0.1327
# Epoch 17/100
# 58/58 [==============================] - 1s 25ms/step - loss: 0.4193 - accuracy: 0.1024 - val_loss: 3.2910 - val_accuracy: 0.1154
# Epoch 18/100
# 58/58 [==============================] - 1s 25ms/step - loss: 0.3399 - accuracy: 0.0939 - val_loss: 3.4422 - val_accuracy: 0.1019
# Epoch 19/100
# 58/58 [==============================] - 1s 25ms/step - loss: 0.3448 - accuracy: 0.1007 - val_loss: 3.5601 - val_accuracy: 0.1365
# Epoch 20/100
# 58/58 [==============================] - 1s 25ms/step - loss: 0.2732 - accuracy: 0.1002 - val_loss: 3.6562 - val_accuracy: 0.1327
# Epoch 21/100
# 58/58 [==============================] - 1s 24ms/step - loss: 0.2136 - accuracy: 0.0958 - val_loss: 3.8077 - val_accuracy: 0.1365
# Epoch 22/100
# 58/58 [==============================] - 1s 25ms/step - loss: 0.2156 - accuracy: 0.0966 - val_loss: 3.8754 - val_accuracy: 0.1154
# Epoch 23/100
# 58/58 [==============================] - 1s 25ms/step - loss: 0.2543 - accuracy: 0.0950 - val_loss: 3.9832 - val_accuracy: 0.1212
# Epoch 24/100
# 58/58 [==============================] - 1s 25ms/step - loss: 0.2314 - accuracy: 0.0931 - val_loss: 4.1954 - val_accuracy: 0.1308
# Epoch 25/100
# 58/58 [==============================] - 1s 25ms/step - loss: 0.2507 - accuracy: 0.0961 - val_loss: 4.2604 - val_accuracy: 0.1615
# Epoch 26/100
# 58/58 [==============================] - 1s 24ms/step - loss: 0.3734 - accuracy: 0.0966 - val_loss: 4.4145 - val_accuracy: 0.1346
# Epoch 27/100
# 58/58 [==============================] - 1s 25ms/step - loss: 0.1652 - accuracy: 0.0975 - val_loss: 4.5265 - val_accuracy: 0.1442
# Epoch 28/100
# 58/58 [==============================] - 1s 25ms/step - loss: 0.1471 - accuracy: 0.0942 - val_loss: 4.5926 - val_accuracy: 0.1365
# Epoch 29/100
# 58/58 [==============================] - 1s 25ms/step - loss: 0.1490 - accuracy: 0.0964 - val_loss: 4.6222 - val_accuracy: 0.1231
# Epoch 30/100
# 58/58 [==============================] - 1s 25ms/step - loss: 0.1542 - accuracy: 0.0950 - val_loss: 4.7458 - val_accuracy: 0.1885
# Epoch 31/100
# 58/58 [==============================] - 1s 25ms/step - loss: 0.1108 - accuracy: 0.0964 - val_loss: 4.7370 - val_accuracy: 0.1750
# Epoch 32/100
# 58/58 [==============================] - 1s 24ms/step - loss: 0.1447 - accuracy: 0.0956 - val_loss: 5.0037 - val_accuracy: 0.1423
# Epoch 33/100
# 58/58 [==============================] - 1s 25ms/step - loss: 0.1146 - accuracy: 0.0956 - val_loss: 5.1046 - val_accuracy: 0.1308
# Epoch 34/100
# 58/58 [==============================] - 1s 25ms/step - loss: 0.1440 - accuracy: 0.0966 - val_loss: 5.2140 - val_accuracy: 0.1077
# Epoch 35/100
# 58/58 [==============================] - 1s 25ms/step - loss: 0.1218 - accuracy: 0.0964 - val_loss: 5.4219 - val_accuracy: 0.1385
# Epoch 36/100
# 58/58 [==============================] - 1s 25ms/step - loss: 0.0910 - accuracy: 0.0947 - val_loss: 5.8596 - val_accuracy: 0.1442
# Epoch 37/100
# 58/58 [==============================] - 1s 25ms/step - loss: 0.1244 - accuracy: 0.0966 - val_loss: 5.9464 - val_accuracy: 0.1365
# Epoch 38/100
# 58/58 [==============================] - 1s 25ms/step - loss: 0.1314 - accuracy: 0.0969 - val_loss: 6.0159 - val_accuracy: 0.1346
# Epoch 39/100
# 58/58 [==============================] - 1s 25ms/step - loss: 0.1346 - accuracy: 0.0956 - val_loss: 6.0980 - val_accuracy: 0.1481
# Epoch 40/100
# 58/58 [==============================] - 1s 25ms/step - loss: 0.0859 - accuracy: 0.0964 - val_loss: 6.3454 - val_accuracy: 0.1423
# Epoch 41/100
# 58/58 [==============================] - 1s 25ms/step - loss: 0.0882 - accuracy: 0.0966 - val_loss: 6.4421 - val_accuracy: 0.1365
# Epoch 42/100
# 58/58 [==============================] - 1s 25ms/step - loss: 0.0975 - accuracy: 0.0950 - val_loss: 6.4498 - val_accuracy: 0.1365
# Epoch 43/100
# 58/58 [==============================] - 1s 25ms/step - loss: 0.1497 - accuracy: 0.0956 - val_loss: 6.5102 - val_accuracy: 0.1250
# Epoch 44/100
# 58/58 [==============================] - 1s 25ms/step - loss: 0.1057 - accuracy: 0.0958 - val_loss: 6.6461 - val_accuracy: 0.1519
# Epoch 45/100
# 58/58 [==============================] - 1s 25ms/step - loss: 0.0978 - accuracy: 0.0964 - val_loss: 6.6412 - val_accuracy: 0.1250
# Epoch 46/100
# 58/58 [==============================] - 1s 25ms/step - loss: 0.0585 - accuracy: 0.0950 - val_loss: 6.7586 - val_accuracy: 0.1269
# Epoch 47/100
# 58/58 [==============================] - 1s 25ms/step - loss: 0.0859 - accuracy: 0.0945 - val_loss: 6.8833 - val_accuracy: 0.1308
# Epoch 48/100
# 58/58 [==============================] - 1s 26ms/step - loss: 0.1082 - accuracy: 0.0956 - val_loss: 6.7666 - val_accuracy: 0.1423
# Epoch 49/100
# 58/58 [==============================] - 1s 25ms/step - loss: 0.0652 - accuracy: 0.0969 - val_loss: 6.8975 - val_accuracy: 0.1385
# Epoch 50/100
# 58/58 [==============================] - 1s 25ms/step - loss: 0.0987 - accuracy: 0.0969 - val_loss: 6.9755 - val_accuracy: 0.1212
# Epoch 51/100
# 58/58 [==============================] - 1s 25ms/step - loss: 0.1167 - accuracy: 0.0950 - val_loss: 6.7620 - val_accuracy: 0.1750
# Epoch 52/100
# 58/58 [==============================] - 1s 25ms/step - loss: 0.1298 - accuracy: 0.0964 - val_loss: 7.2577 - val_accuracy: 0.1654
# Epoch 53/100
# 58/58 [==============================] - 1s 26ms/step - loss: 0.1087 - accuracy: 0.0958 - val_loss: 7.4996 - val_accuracy: 0.1654
# Epoch 54/100
# 58/58 [==============================] - 2s 27ms/step - loss: 0.0777 - accuracy: 0.0964 - val_loss: 7.4285 - val_accuracy: 0.1827
# Epoch 55/100
# 58/58 [==============================] - 1s 25ms/step - loss: 0.1020 - accuracy: 0.0958 - val_loss: 7.4254 - val_accuracy: 0.1750
# Epoch 56/100
# 58/58 [==============================] - 1s 25ms/step - loss: 0.0927 - accuracy: 0.0975 - val_loss: 7.4250 - val_accuracy: 0.1462
# Epoch 57/100
# 58/58 [==============================] - 1s 25ms/step - loss: 0.0662 - accuracy: 0.0961 - val_loss: 7.4121 - val_accuracy: 0.1442
# Epoch 58/100
# 58/58 [==============================] - 1s 25ms/step - loss: 0.1276 - accuracy: 0.0958 - val_loss: 7.5707 - val_accuracy: 0.1538
# Epoch 59/100
# 58/58 [==============================] - 1s 25ms/step - loss: 0.1162 - accuracy: 0.0961 - val_loss: 7.3561 - val_accuracy: 0.1712
# Epoch 60/100
# 58/58 [==============================] - 1s 26ms/step - loss: 0.0601 - accuracy: 0.0961 - val_loss: 7.3910 - val_accuracy: 0.1577
# Epoch 61/100
# 58/58 [==============================] - 1s 25ms/step - loss: 0.0611 - accuracy: 0.0956 - val_loss: 7.2032 - val_accuracy: 0.1577
# Epoch 62/100
# 58/58 [==============================] - 1s 25ms/step - loss: 0.0749 - accuracy: 0.0961 - val_loss: 7.1720 - val_accuracy: 0.1596
# Epoch 63/100
# 58/58 [==============================] - 1s 25ms/step - loss: 0.0452 - accuracy: 0.0961 - val_loss: 7.4864 - val_accuracy: 0.1365
# Epoch 64/100
# 58/58 [==============================] - 1s 25ms/step - loss: 0.0441 - accuracy: 0.0956 - val_loss: 7.5780 - val_accuracy: 0.1596
# Epoch 65/100
# 58/58 [==============================] - 1s 25ms/step - loss: 0.0894 - accuracy: 0.0969 - val_loss: 7.7808 - val_accuracy: 0.1577
# Epoch 66/100
# 58/58 [==============================] - 1s 25ms/step - loss: 0.1019 - accuracy: 0.0972 - val_loss: 7.6862 - val_accuracy: 0.1519
# Epoch 67/100
# 58/58 [==============================] - 1s 25ms/step - loss: 0.0643 - accuracy: 0.0958 - val_loss: 7.6825 - val_accuracy: 0.1212
# Epoch 68/100
# 58/58 [==============================] - 2s 27ms/step - loss: 0.0295 - accuracy: 0.0958 - val_loss: 7.8051 - val_accuracy: 0.1365
# Epoch 69/100
# 58/58 [==============================] - 1s 26ms/step - loss: 0.0421 - accuracy: 0.0950 - val_loss: 7.9859 - val_accuracy: 0.1558
# Epoch 70/100
# 58/58 [==============================] - 1s 25ms/step - loss: 0.0933 - accuracy: 0.0961 - val_loss: 7.8340 - val_accuracy: 0.1423
# Epoch 71/100
# 58/58 [==============================] - 1s 25ms/step - loss: 0.0717 - accuracy: 0.0953 - val_loss: 7.8940 - val_accuracy: 0.1519
# Epoch 72/100
# 58/58 [==============================] - 1s 25ms/step - loss: 0.1426 - accuracy: 0.0958 - val_loss: 7.7934 - val_accuracy: 0.1654
# Epoch 73/100
# 58/58 [==============================] - 1s 25ms/step - loss: 0.0425 - accuracy: 0.0966 - val_loss: 7.8573 - val_accuracy: 0.1596
# Epoch 74/100
# 26/58 [============>.................] - ETA: 0s - loss: 0.0199 - accuracy: 0.1010
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-33-6ad7404bc999> in <module>
#       3     train_set,
#       4     validation_data=val_set,
# ----> 5     epochs=EPOCHS,
#       6 )
#       7
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1098                 _r=1):
#    1099               callbacks.on_train_batch_begin(step)
# -> 1100               tmp_logs = self.train_function(iterator)
#    1101               if data_handler.should_sync:
#    1102                 context.async_wait()
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     826     tracing_count = self.experimental_get_tracing_count()
#     827     with trace.Trace(self._name) as tm:
# --> 828       result = self._call(*args, **kwds)
#     829       compiler = "xla" if self._experimental_compile else "nonXla"
#     830       new_tracing_count = self.experimental_get_tracing_count()
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     853       # In this case we have created variables on the first call, so we run the
#     854       # defunned version which is guaranteed to never create variables.
# --> 855       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     856     elif self._stateful_fn is not None:
#     857       # Release the lock early so that multiple threads can perform the call
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2941        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2942     return graph_function._call_flat(
# -> 2943         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2944
#    2945   @property
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1917       # No tape is watching; skip to running the function.
#    1918       return self._build_call_outputs(self._inference_function.call(
# -> 1919           ctx, args, cancellation_manager=cancellation_manager))
#    1920     forward_backward = self._select_forward_and_backward_functions(
#    1921         args,
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     558               inputs=args,
#     559               attrs=attrs,
# --> 560               ctx=ctx)
#     561         else:
#     562           outputs = execute.execute_with_cancellation(
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:
